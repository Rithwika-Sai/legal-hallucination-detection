# %% [markdown]
# <a href="https://colab.research.google.com/github/Rithwika-Sai/legal-hallucination-detection/blob/main/self_cons_mistral_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-d5ce26eb-9d08-44eb-a174-7eddb9d1246e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d5ce26eb-9d08-44eb-a174-7eddb9d1246e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls
# Out:
# sample_data  self_cons_mistral.py  test.json

# %%
# !python self_cons_mistral.py
# Out:
# ...
# config.json: 100% 596/596 [00:00<00:00, 3.00MB/s]
# tokenizer_config.json: 100% 2.10k/2.10k [00:00<00:00, 7.68MB/s]
# tokenizer.json: 100% 1.80M/1.80M [00:00<00:00, 28.1MB/s]
# tokenizer.model: 100% 493k/493k [00:00<00:00, 831kB/s]
# special_tokens_map.json: 100% 414/414 [00:00<00:00, 2.09MB/s]
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 100% 25.1k/25.1k [00:00<00:00, 61.3MB/s]
# ...
# Fetching 3 files: 100% 3/3 [03:15<00:00, 65.18s/it]
# Download complete: 100% 14.5G/14.5G [03:15<00:00, 74.0MB/s]
# Loading weights: 100% 291/291 [00:59<00:00,  4.87it/s]
# generation_config.json: 100% 111/111 [00:00<00:00, 570kB/s]
# Some parameters are on the meta device because they were offloaded to the cpu.
# modules.json: 100% 349/349 [00:00<00:00, 2.20MB/s]
# config_sentence_transformers.json: 100% 116/116 [00:00<00:00, 216kB/s]
# README.md: 100% 10.5k/10.5k [00:00<00:00, 32.9MB/s]
# ...
